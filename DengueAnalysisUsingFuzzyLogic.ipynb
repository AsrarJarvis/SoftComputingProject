# %%
# !pip install Scikit-fuzzy
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# %%
Fever=ctrl.Antecedent(np.arange(95,105,1), 'Fever')
MusclePain=ctrl.Antecedent(np.arange(0,11,1), 'MusclePain')
Vomiting=ctrl.Antecedent(np.arange(0,11,1),'Vomiting')
Cold_cough=ctrl.Antecedent(np.arange(0,11,1),'Cold_cough')
Dengue=ctrl.Consequent(np.arange(0,101, 1), 'Dengue')

# %%
Fever=ctrl.Antecedent(np.arange(95,105,1), 'Fever')
MusclePain=ctrl.Antecedent(np.arange(0,11,1), 'MusclePain')
Vomiting=ctrl.Antecedent(np.arange(0,11,1),'Vomiting')
Cold_cough=ctrl.Antecedent(np.arange(0,11,1),'Cold_cough')
Dengue=ctrl.Consequent(np.arange(0,101, 1), 'Dengue')

# %%
Dengue.view()
# Out:
# C:\Users\Jarvis\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
Fever['low']=fuzz.trimf(Fever.universe,[95,95,98])
Fever['medium']=fuzz.trimf(Fever.universe, [96,99,102])
Fever['high']=fuzz.trimf(Fever.universe, [100,102,104])

# %%
Cold_cough['No']=fuzz.trimf(Cold_cough.universe,[0,0,4])
Cold_cough['Maybe']=fuzz.trimf(Cold_cough.universe,[2,4,8])
Cold_cough['Yes']=fuzz.trimf(Cold_cough.universe,[6,10,10])

# %%
Cold_cough.view()
# Out:
# C:\Users\Jarvis\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
Fever.view()
# Out:
# C:\Users\Jarvis\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
MusclePain['No']=fuzz.trimf(MusclePain.universe,[0,0,4])
MusclePain['Maybe']=fuzz.trimf(MusclePain.universe, [2,4,8])
MusclePain['Yes']=fuzz.trimf(MusclePain.universe, [6,10,10])

# %%
MusclePain.view()
# Out:
# C:\Users\Jarvis\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
Vomiting['No']=fuzz.trimf(Vomiting.universe,[0,0,4])
Vomiting['Maybe']=fuzz.trimf(Vomiting.universe, [2,4,8])
Vomiting['Yes']=fuzz.trimf(Vomiting.universe, [6,10,10])

# %%
Vomiting.view()
# Out:
# C:\Users\Jarvis\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
rule1=ctrl.Rule(Fever['low']| MusclePain['No']| Vomiting['No']| Cold_cough['No'], Dengue['No'])
rule2=ctrl.Rule(Fever['low']| MusclePain['No']| Vomiting['No']| Cold_cough['Maybe'], Dengue['No'])
rule3=ctrl.Rule(Fever['low']| MusclePain['No']| Vomiting['No']| Cold_cough['Yes'], Dengue['No'])
rule4=ctrl.Rule(Fever['low']| MusclePain['No']| Vomiting['Maybe']| Cold_cough['No'], Dengue['No'])
rule5=ctrl.Rule(Fever['low']| MusclePain['No']| Vomiting['Maybe']| Cold_cough['Maybe'], Dengue['No'])
rule6=ctrl.Rule(Fever['low']| MusclePain['No']| Vomiting['Maybe']| Cold_cough['Yes'], Dengue['No'])
rule7=ctrl.Rule(Fever['low']| MusclePain['No']| Vomiting['Yes']| Cold_cough['No'], Dengue['No'])
rule8=ctrl.Rule(Fever['low']| MusclePain['No']| Vomiting['Yes']| Cold_cough['Maybe'], Dengue['No'])
rule9=ctrl.Rule(Fever['low']| MusclePain['No']| Vomiting['Yes']| Cold_cough['Yes'], Dengue['No'])
rule10=ctrl.Rule(Fever['low']| MusclePain['Maybe']| Vomiting['No']| Cold_cough['No'], Dengue['No'])
rule11=ctrl.Rule(Fever['low']| MusclePain['Maybe']| Vomiting['No']| Cold_cough['Maybe'], Dengue['No'])
rule12=ctrl.Rule(Fever['low']| MusclePain['Maybe']| Vomiting['No']| Cold_cough['Yes'], Dengue['No'])
rule13=ctrl.Rule(Fever['low']| MusclePain['Maybe']| Vomiting['Maybe']| Cold_cough['No'], Dengue['No'])
rule14=ctrl.Rule(Fever['low']| MusclePain['Maybe']| Vomiting['Maybe']| Cold_cough['Maybe'], Dengue['No'])
rule15=ctrl.Rule(Fever['low']| MusclePain['Maybe']| Vomiting['Maybe']| Cold_cough['Yes'], Dengue['No'])
rule16=ctrl.Rule(Fever['low']| MusclePain['Maybe']| Vomiting['Yes']| Cold_cough['No'], Dengue['No'])
rule17=ctrl.Rule(Fever['low']| MusclePain['Maybe']| Vomiting['Yes']| Cold_cough['Maybe'], Dengue['No'])
rule18=ctrl.Rule(Fever['low']| MusclePain['Maybe']| Vomiting['Yes']| Cold_cough['Yes'], Dengue['No'])
rule19=ctrl.Rule(Fever['low']| MusclePain['Yes']| Vomiting['No']| Cold_cough['No'], Dengue['No'])
rule20=ctrl.Rule(Fever['low']| MusclePain['Yes']| Vomiting['No']| Cold_cough['Maybe'], Dengue['No'])
rule21=ctrl.Rule(Fever['low']| MusclePain['Yes']| Vomiting['No']| Cold_cough['Yes'], Dengue['No'])
rule22=ctrl.Rule(Fever['low']| MusclePain['Yes']| Vomiting['Maybe']| Cold_cough['No'], Dengue['No'])
rule23=ctrl.Rule(Fever['low']| MusclePain['Yes']| Vomiting['Maybe']| Cold_cough['Maybe'], Dengue['No'])
rule24=ctrl.Rule(Fever['low']| MusclePain['Yes']| Vomiting['Maybe']| Cold_cough['Yes'], Dengue['No'])
rule25=ctrl.Rule(Fever['low']| MusclePain['Yes']| Vomiting['Yes']| Cold_cough['No'], Dengue['No'])
rule26=ctrl.Rule(Fever['low']| MusclePain['Yes']| Vomiting['Yes']| Cold_cough['Maybe'], Dengue['No'])
rule27=ctrl.Rule(Fever['low']| MusclePain['Yes']| Vomiting['Yes']| Cold_cough['Yes'], Dengue['No'])
rule28=ctrl.Rule(Fever['medium']| MusclePain['No']| Vomiting['No']| Cold_cough['No'], Dengue['Maybe'])
rule29=ctrl.Rule(Fever['medium']| MusclePain['No']| Vomiting['No']| Cold_cough['Maybe'], Dengue['Maybe'])
rule30=ctrl.Rule(Fever['medium']| MusclePain['No']| Vomiting['No']| Cold_cough['Yes'], Dengue['Maybe'])
rule30=ctrl.Rule(Fever['medium']| MusclePain['No']| Vomiting['No']| Cold_cough['Yes'], Dengue['Maybe'])
rule31=ctrl.Rule(Fever['medium']| MusclePain['No']| Vomiting['Maybe']| Cold_cough['No'], Dengue['Maybe'])
rule32=ctrl.Rule(Fever['medium']| MusclePain['No']| Vomiting['Maybe']| Cold_cough['Maybe'], Dengue['Maybe'])
rule33=ctrl.Rule(Fever['medium']| MusclePain['No']| Vomiting['Maybe']| Cold_cough['Yes'], Dengue['Maybe'])
rule34=ctrl.Rule(Fever['medium']| MusclePain['No']| Vomiting['Yes']| Cold_cough['No'], Dengue['Maybe'])
rule35=ctrl.Rule(Fever['medium']| MusclePain['No']| Vomiting['Yes']| Cold_cough['Maybe'], Dengue['Maybe'])
rule36=ctrl.Rule(Fever['medium']| MusclePain['No']| Vomiting['Yes']| Cold_cough['Yes'], Dengue['Maybe'])
rule37=ctrl.Rule(Fever['medium']| MusclePain['Maybe']| Vomiting['No']| Cold_cough['No'], Dengue['Maybe'])
rule38=ctrl.Rule(Fever['medium']| MusclePain['Maybe']| Vomiting['No']| Cold_cough['Maybe'], Dengue['Maybe'])
rule39=ctrl.Rule(Fever['medium']| MusclePain['Maybe']| Vomiting['No']| Cold_cough['Yes'], Dengue['Maybe'])
rule40=ctrl.Rule(Fever['medium']| MusclePain['Maybe']| Vomiting['Maybe']| Cold_cough['No'], Dengue['Maybe'])
rule41=ctrl.Rule(Fever['medium']| MusclePain['Maybe']| Vomiting['Maybe']| Cold_cough['Maybe'], Dengue['Maybe'])
rule42=ctrl.Rule(Fever['medium']| MusclePain['Maybe']| Vomiting['Maybe']| Cold_cough['Yes'], Dengue['Maybe'])
rule43=ctrl.Rule(Fever['medium']| MusclePain['Maybe']| Vomiting['Yes']| Cold_cough['No'], Dengue['Maybe'])
rule44=ctrl.Rule(Fever['medium']| MusclePain['Maybe']| Vomiting['Yes']| Cold_cough['Maybe'], Dengue['Maybe'])
rule45=ctrl.Rule(Fever['medium']| MusclePain['Maybe']| Vomiting['Yes']| Cold_cough['Yes'], Dengue['Maybe'])
rule46=ctrl.Rule(Fever['medium']| MusclePain['Yes']| Vomiting['No']| Cold_cough['No'], Dengue['Maybe'])
rule47=ctrl.Rule(Fever['medium']| MusclePain['Yes']| Vomiting['No']| Cold_cough['Maybe'], Dengue['Maybe'])
rule48=ctrl.Rule(Fever['medium']| MusclePain['Yes']| Vomiting['No']| Cold_cough['Yes'], Dengue['Maybe'])
rule49=ctrl.Rule(Fever['medium']| MusclePain['Yes']| Vomiting['Maybe']| Cold_cough['No'], Dengue['Maybe'])
rule50=ctrl.Rule(Fever['medium']| MusclePain['Yes']| Vomiting['Maybe']| Cold_cough['Maybe'], Dengue['Maybe'])
rule51=ctrl.Rule(Fever['medium']| MusclePain['Yes']| Vomiting['Maybe']| Cold_cough['Yes'], Dengue['Maybe'])
rule52=ctrl.Rule(Fever['medium']| MusclePain['Yes']| Vomiting['Yes']| Cold_cough['No'], Dengue['Maybe'])
rule53=ctrl.Rule(Fever['medium']| MusclePain['Yes']| Vomiting['Yes']| Cold_cough['Maybe'], Dengue['Maybe'])
rule54=ctrl.Rule(Fever['medium']| MusclePain['Yes']| Vomiting['Yes']| Cold_cough['Yes'], Dengue['Maybe'])
rule55=ctrl.Rule(Fever['high']| MusclePain['No']| Vomiting['No']| Cold_cough['No'], Dengue['Yes'])
rule56=ctrl.Rule(Fever['high']| MusclePain['No']| Vomiting['No']| Cold_cough['Maybe'], Dengue['Yes'])
rule57=ctrl.Rule(Fever['high']| MusclePain['No']| Vomiting['No']| Cold_cough['Yes'], Dengue['Yes'])
rule58=ctrl.Rule(Fever['high']| MusclePain['No']| Vomiting['Maybe']| Cold_cough['No'], Dengue['Yes'])
rule59=ctrl.Rule(Fever['high']| MusclePain['No']| Vomiting['Maybe']| Cold_cough['Maybe'], Dengue['Yes'])
rule60=ctrl.Rule(Fever['high']| MusclePain['No']| Vomiting['Maybe']| Cold_cough['Yes'], Dengue['Yes'])
rule61=ctrl.Rule(Fever['high']| MusclePain['No']| Vomiting['Yes']| Cold_cough['No'], Dengue['Yes'])
rule62=ctrl.Rule(Fever['high']| MusclePain['No']| Vomiting['Yes']| Cold_cough['Maybe'], Dengue['Yes'])
rule63=ctrl.Rule(Fever['high']| MusclePain['No']| Vomiting['Yes']| Cold_cough['Yes'], Dengue['Yes'])
rule64=ctrl.Rule(Fever['high']| MusclePain['Maybe']| Vomiting['No']| Cold_cough['No'], Dengue['Yes'])
rule65=ctrl.Rule(Fever['high']| MusclePain['Maybe']| Vomiting['No']| Cold_cough['Maybe'], Dengue['Yes'])
rule66=ctrl.Rule(Fever['high']| MusclePain['Maybe']| Vomiting['No']| Cold_cough['Yes'], Dengue['Yes'])
rule67=ctrl.Rule(Fever['high']| MusclePain['Maybe']| Vomiting['Maybe']| Cold_cough['No'], Dengue['Yes'])
rule68=ctrl.Rule(Fever['high']| MusclePain['Maybe']| Vomiting['Maybe']| Cold_cough['Maybe'], Dengue['Yes'])
rule69=ctrl.Rule(Fever['high']| MusclePain['Maybe']| Vomiting['Maybe']| Cold_cough['Yes'], Dengue['Yes'])
rule70=ctrl.Rule(Fever['high']| MusclePain['Maybe']| Vomiting['Yes']| Cold_cough['No'], Dengue['Yes'])
rule71=ctrl.Rule(Fever['high']| MusclePain['Maybe']| Vomiting['Yes']| Cold_cough['Maybe'], Dengue['Yes'])
rule72=ctrl.Rule(Fever['high']| MusclePain['Maybe']| Vomiting['Yes']| Cold_cough['Yes'], Dengue['Yes'])
rule73=ctrl.Rule(Fever['high']| MusclePain['Yes']| Vomiting['No']| Cold_cough['No'], Dengue['Yes'])
rule74=ctrl.Rule(Fever['high']| MusclePain['Yes']| Vomiting['No']| Cold_cough['Maybe'], Dengue['Yes'])
rule75=ctrl.Rule(Fever['high']| MusclePain['Yes']| Vomiting['No']| Cold_cough['Yes'], Dengue['Yes'])
rule76=ctrl.Rule(Fever['high']| MusclePain['Yes']| Vomiting['Maybe']| Cold_cough['No'], Dengue['Yes'])
rule77=ctrl.Rule(Fever['high']| MusclePain['Yes']| Vomiting['Maybe']| Cold_cough['Maybe'], Dengue['Yes'])
rule78=ctrl.Rule(Fever['high']| MusclePain['Yes']| Vomiting['Maybe']| Cold_cough['Yes'], Dengue['Yes'])
rule79=ctrl.Rule(Fever['high']| MusclePain['Yes']| Vomiting['Yes']| Cold_cough['No'], Dengue['Yes'])
rule80=ctrl.Rule(Fever['high']| MusclePain['Yes']| Vomiting['Yes']| Cold_cough['Maybe'], Dengue['Yes'])
rule81=ctrl.Rule(Fever['high']| MusclePain['Yes']| Vomiting['Yes']| Cold_cough['Yes'], Dengue['Yes'])

# %%
rule1.view()
rule2.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x200d6752c48>)

# %%
Dengue_ctrl=ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8, rule9, rule10, rule11,rule12,rule13,rule14,
                                rule15, rule16, rule17, rule18, rule19,rule20, rule21, rule22, rule23, rule24, rule25,rule26,rule27,rule28,
                                rule29, rule30, rule31, rule32, rule33,rule34, rule35, rule36, rule37, rule38, rule39,rule40,rule41,rule42,
                                rule43, rule44, rule45, rule46, rule47,rule48, rule49, rule50, rule51, rule52, rule53,rule54,rule55,rule56,
                               rule57, rule58, rule59, rule60, rule61,rule62, rule63, rule64, rule65, rule66, rule67,rule68,rule69,rule70,
                               rule71, rule72, rule73, rule74, rule75,rule76, rule77, rule78, rule79, rule80, rule81])

# %%
Occur=ctrl.ControlSystemSimulation(Dengue_ctrl)

# %%
Occur.input['Fever']=float(input("Enter the temperature "))
Occur.input['MusclePain']=float(input("Enter the value "))
Occur.input['Vomiting']=float(input("Enter the value1 "))
Occur.input['Cold_cough']=float(input("Enter the value2 "))
Occur.compute()
print(Occur.output['Dengue'])
Dengue.view(sim=Occur)
# Out:
# Enter the temperature 102
# Enter the value 4
# Enter the value1 3
# Enter the value2 4
# 48.75613556680949
# C:\Users\Jarvis\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
